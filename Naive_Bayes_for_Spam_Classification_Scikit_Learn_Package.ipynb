# %% [markdown]
# ## Naive Bayes for Spam Classification - Scikit Learn
#
# The scikit learn library has a Naive Bayes probabilistic model pre-defined!

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer # Will help us to generate our vocabulary
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB # Naive Bayes Classifier (why not try random forest?)

from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

DATA_JSON_FILE = '/content/drive/My Drive/SpamData/01_Processing/email-text-data.json'

# %%
# Loading our data with pandas!
data = pd.read_json(DATA_JSON_FILE) # Tip: JSON files are good given the web uses Json often! and it is easy to retrieve data

print('Data Frame Shape:', data.shape)
data.tail()
# Out:
# Data Frame Shape: (5797, 3)
#                                                 Message  ...                               File_Name
# 5792  On Fri, Jul 19, 2002 at 03:35:36PM +0100 or so...  ...  00109.1d90dc88e6b0591ee91e3cd605ec778a
# 5793    | Date: Wed, 31 Jul 2002 15:13:23 +0100\n\n ...  ...  00190.598d2a83744a3a7ac536e36ca56d7e65
# 5794  gcc, glibc and binutils, which the lfs site sa...  ...  00123.3921de802520cfe7a5b3e0777aa4affc
# 5795  --==_Exmh_-2079003886P\n\nContent-Type: text/p...  ...  00008.6b73027e1e56131377941ff1db17ff12
# 5796  On Sat, Jul 27, 2002 at 03:06:15PM +0100, Step...  ...  00125.e6d80b873b71ae5324679a4dbefe4eaf
#
# [5 rows x 3 columns]

# %%
# Sorting by our index
data.sort_index(inplace=True)

# %%
# Generating our Vocabulary 

# This function will generate automatically a vocabulary using english language
vectorizer = CountVectorizer(stop_words='english')

# %%
# The vectorizer will extract all features from our Messages 
all_features = vectorizer.fit_transform(data.Message)

all_features.shape
# 5797 >> Rows
# 102694 >> Columns = Tokens in our e-mails (individual words)
# Out:
# (5797, 102694)

# %%
# Vocabulary generated by Scikit Learn
vectorizer.vocabulary_
# Out:
# {'html': 48472,
#  'head': 47011,
#  'title': 87725,
#  'digital': 34034,
#  'publishing': 74032,
#  'tools': 88162,
#  'free': 42773,
#  'software': 83094,
#  'alert': 18591,
#  'meta': 61701,
#  'http': 48497,
#  'equiv': 38991,
#  'content': 30249,
#  'type': 89371,
#  'text': 86991,
#  'charset': 27796,
#  'iso': 53094,
#  '8859': 12828,
#  'body': 24390,
#  'bgcolor': 23297,
#  'ffffff': 41323,
#  '000000': 4,
#  'center': 27405,
#  'table': 86120,
#  'width': 95488,
#  '582': 9382,
#  'border': 24581,
#  'cellspacing': 27383,
#  'cellpadding': 27375,
#  'bordercolor': 24584,
#  '0077cc': 261,
#  'tr': 88442,
#  'td': 86548,
#  'colspan': 29390,
#  'align': 18634,
#  '8749mtdf5': 12778,
#  '466pbl14': 8223,
#  'href': 48390,
#  '3dpageturningebook': 7150,
#  'com': 29405,
#  'style': 84723,
#  'decoration': 32851,
#  'font': 42257,
#  'face': 40498,
#  'verdana': 92415,
#  'arial': 20116,
#  'helvetica': 47220,
#  'sans': 80256,
#  'serif': 81304,
#  'size': 82347,
#  'color': 29367,
#  'publish': 74027,
#  'like': 58501,
#  'professional': 73364,
#  '204': 3709,
#  'valign': 92046,
#  '000066': 33,
#  'easily': 37275,
#  'create': 30953,
#  'ul': 90225,
#  'li': 58293,
#  'ebooks': 37381,
#  'ebrochures': 37386,
#  'ecatalogs': 37411,
#  'resumes': 77951,
#  'newsletters': 65067,
#  'presentations': 73043,
#  'magazines': 60258,
#  'photo': 71334,
#  'albums': 18563,
#  'invitations': 52618,
#  '264': 4563,
#  'save': 80370,
#  'money': 62840,
#  'trees': 88704,
#  'br': 24813,
#  'printing': 73203,
#  'postage': 72593,
#  'advertising': 17349,
#  'costs': 30587,
#  '000099': 41,
#  'download': 35152,
#  'new': 64988,
#  'version': 92460,
#  'limited': 58543,
#  'time': 87625,
#  'offer': 67158,
#  'choose': 28071,
#  'display': 34406,
#  'styles': 84726,
#  '3d': 6385,
#  'page': 69156,
#  'turn': 89138,
#  'slide': 82609,
#  'sweep': 85433,
#  'wipe': 95660,
#  'embed': 38271,
#  'hyperlinks': 48814,
#  'link': 58601,
#  'online': 67665,
#  'website': 95049,
#  'order': 68036,
#  'contact': 30198,
#  'form': 42425,
#  'distribute': 34493,
#  'floppy': 42012,
#  'cd': 27206,
#  'rom': 78893,
#  'mail': 60312,
#  'marketing': 60798,
#  'level': 58120,
#  '384': 6154,
#  'info': 51836,
#  'samples': 80195,
#  'click': 28719,
#  'appropriate': 19826,
#  'right': 78422,
#  'nbsp': 64561,
#  'server': 81344,
#  'demand': 33124,
#  'extremely': 40090,
#  'high': 47526,
#  'try': 88914,
#  'links': 58616,
#  'periodically': 70507,
#  'site': 82284,
#  'slow': 82666,
#  'unreachable': 90885,
#  'theygo': 87298,
#  'freesoftware': 42845,
#  'www': 96531,
#  'digitalpublishingtools': 34047,
#  'action': 16898,
#  'unsubscribe': 90955,
#  'asp': 20429,
#  'method': 61737,
#  'post': 72590,
#  'wish': 95691,
#  'removed': 77482,
#  'mailing': 60381,
#  'list': 58680,
#  'cick': 28268,
#  'button': 25602,
#  'input': 52071,
#  '25': 4433,
#  'value': 92060,
#  'zzzz': 101425,
#  'jmason': 54509,
#  'org': 68066,
#  'submit': 84812,
#  'hidden': 47506,
#  'unsub': 90952,
#  'copyright': 30464,
#  '2002': 3508,
#  'affiliate': 17576,
#  'id': 49828,
#  '1269': 2043,
#  'fully': 43250,
#  'functional': 43264,
#  'expiration': 39931,
#  'spread': 83734,
#  'limit': 58539,
#  'email': 38216,
#  'works': 96058,
#  'way': 94335,
#  'medium': 61449,
#  'let': 58083,
#  'share': 81646,
#  'people': 70441,
#  'cost': 30578,
#  'small': 82730,
#  'classified': 28618,
#  'ad': 16973,
#  'access': 16655,
#  'targeted': 86351,
#  'exchange': 39702,
#  'members': 61538,
#  'old': 67460,
#  'lists': 58733,
#  'ones': 67646,
#  'million': 62115,
#  'fresh': 42894,
#  'general': 44238,
#  'emails': 38248,
#  'week': 95087,
#  'services': 81361,
#  'buyers': 25617,
#  'key': 55874,
#  'signup': 82103,
#  'today': 88039,
#  '68': 10469,
#  '62': 10140,
#  '73': 11215,
#  '31': 5688,
#  'membership': 61539,
#  'message': 61680,
#  'emailed': 38235,
#  'guaranteed': 45873,
#  'increase': 51582,
#  'lift': 58464,
#  'firm': 41690,
#  'breasts': 24945,
#  '60': 10038,
#  'days': 32422,
#  '100': 1496,
#  'herbal': 47266,
#  'natural': 64477,
#  'proven': 73655,
#  'formula': 42462,
#  '1996': 2916,
#  'bust': 25573,
#  'sizes': 82351,
#  '30': 5593,
#  '202': 3687,
#  '101': 1549,
#  '163': 2494,
#  '34': 5921,
#  '81': 12114,
#  'wangxd': 94149,
#  'absolutely': 16493,
#  'effects': 37703,
#  'self': 81125,
#  'confident': 29897,
#  'comfortable': 29447,
#  'bed': 22866,
#  'need': 64740,
#  'support': 85179,
#  'bra': 24819,
#  'know': 56461,
#  'trust': 88897,
#  'receiving': 76794,
#  'double': 35104,
#  'opt': 67895,
#  'subscriber': 84839,
#  'standard': 84076,
#  'affiliates': 17584,
#  'remove': 77467,
#  'related': 77302,
#  'just': 55049,
#  '64': 10230,
#  '123': 2001,
#  '160': 2463,
#  '91': 13633,
#  'gg': 44485,
#  'unsubscriber': 90962,
#  'userid': 91361,
#  'netcomuk': 64893,
#  'uk': 90148,
#  'sexy': 81461,
#  'animals': 19287,
#  'doing': 34927,
#  'wild': 95516,
#  'thing': 87320,
#  'super': 85106,
#  'hot': 48223,
#  'internet': 52404,
#  'heard': 47078,
#  'rated': 76348,
#  'number': 66246,
#  'adult': 17302,
#  'years': 98506,
#  'row': 79047,
#  'thousands': 87420,
#  'pics': 71515,
#  'hardcore': 46679,
#  'fucking': 43201,
#  'cum': 31368,
#  'shots': 81874,
#  'pet': 70667,
#  'girl': 44713,
#  'videos': 92727,
#  'waiting': 94062,
#  'lspeedhost': 59550,
#  'net': 64868,
#  'wfs': 95233,
#  'aid': 18121,
#  '283360': 4726,
#  '18': 2693,
#  'enter': 38703,
#  'received': 76784,
#  'advertisement': 17344,
#  'opted': 67899,
#  'receive': 76783,
#  'offers': 67168,
#  'specials': 83517,
#  'affiliated': 17581,
#  'websites': 95051,
#  'error': 39109,
#  'database': 32322,
#  'clicking': 28730,
#  '16': 2462,
#  'alw': 18853,
#  'takemeoff': 86223,
#  'allow': 18722,
#  '24hours': 4410,
#  'removal': 77461,
#  'sent': 81223,
#  'compliance': 29680,
#  'information': 51875,
#  'promotion': 73491,
#  'privacy': 73225,
#  'protection': 73615,
#  'act': 16884,
#  'section': 80998,
#  '50': 8926,
#  'marked': 60787,
#  'valid': 92036,
#  'instruction': 52222,
#  'nkiys5': 65471,
#  'cell': 27364,
#  'booster': 24545,
#  'antenna': 19433,
#  '3diso': 7050,
#  'bord': 24578,
#  'ercolor': 39025,
#  'ff9933': 41266,
#  'si': 81984,
#  'ze': 100072,
#  'strong': 84630,
#  'boost': 24543,
#  'reception': 76803,
#  'geneva': 44275,
#  'em': 38188,
#  'phone': 71311,
#  'cordless': 30480,
#  'elvetica': 38179,
#  '300': 5594,
#  'clarity': 28599,
#  'stron': 84629,
#  'don': 34992,
#  'buy': 25611,
#  'bad': 22206,
#  'recepiton': 76801,
#  'improve': 51396,
#  'communication': 29550,
#  'instantly': 52201,
#  'simply': 82183,
#  'installing': 52185,
#  'chip': 28007,
#  '009933': 278,
#  'powerful': 72700,
#  '70': 11063,
#  'seen': 81064,
#  'ff6600': 41253,
#  'product': 73337,
#  'compares': 29594,
#  'ultra': 90288,
#  'transparent': 88613,
#  'installs': 52189,
#  'second': 80968,
#  'power': 72689,
#  '4ft': 8543,
#  'dropped': 36243,
#  'interrupted': 52437,
#  'calls': 26535,
#  'work': 96033,
#  'place': 71899,
#  'singal': 82223,
#  'weak': 94937,
#  'advertised': 17342,
#  'times': 87641,
#  'price': 73136,
#  '0066ff': 254,
#  'helveti': 47218,
#  'ca': 26367,
#  '234sj': 4268,
#  'cellbooster': 27367,
#  'welcom': 95136,
#  'affid': 17569,
#  '3d1003': 6420,
#  'ff0033': 41236,
#  'gene': 44234,
#  'va': 91980,
#  'easy': 37289,
#  'install': 52177,
#  'remov': 77459,
#  'mime': 62140,
#  'format': 42435,
#  'reader': 76618,
#  'does': 34891,
#  'understand': 90570,
#  'legible': 57979,
#  '_nextpart_caramail_0190361032516937_id': 15173,
#  'plain': 71912,
#  'ascii': 20348,
#  'transfer': 88556,
#  'encoding': 38472,
#  '7bit': 11595,
#  'senior': 81202,
#  'advocate': 17378,
#  'nigeria': 65310,
#  'barr': 22457,
#  'williams': 95547,
#  'falana': 40604,
#  'san': 80206,
#  'dear': 32719,
#  'sir': 82261,
#  'barrister': 22472,
#  'member': 61536,
#  'bar': 22399,
#  'association': 20518,
#  'nba': 64536,
#  'reached': 76595,
#  'world': 96070,
#  'business': 25553,
#  'encyclopaedia': 38495,
#  'mind': 62166,
#  'introduce': 52520,
#  'confidence': 29895,
#  'mutual': 63781,
#  'benefit': 23038,
#  'sum': 85033,
#  'usd48m': 91308,
#  'united': 90759,
#  'states': 84184,
#  'lodged': 59126,
#  'security': 81026,
#  'company': 29579,
#  'country': 30655,
#  'late': 57585,
#  'state': 84171,
#  'gen': 44227,
#  'sani': 80243,
#  'abacha': 16312,
#  'safe': 80067,
#  'keeping': 55778,
#  'vaults': 92151,
#  'boxes': 24708,
#  'labelled': 57358,
#  'personal': 70607,
#  'belongings': 23012,
#  'true': 88876,
#  'originally': 68115,
#  'meant': 61370,
#  'used': 91322,
#  'political': 72356,
#  'campaign': 26583,
#  'family': 40651,
#  'attorney': 20753,
#  'confided': 29893,
#  'relevant': 77349,
#  'document': 34867,
#  'papers': 69349,
#  'relating': 77304,
#  'deposit': 33264,
#  'died': 33967,
#  'cardiac': 26771,
#  'arrest': 20197,
#  'matter': 60975,
#  'fact': 40520,
#  'concluded': 29815,
#  'arrangement': 20190,
#  'offshore': 67205,
#  'consignment': 30098,
#  'diplomatic': 34140,
#  'means': 61369,
#  'office': 67173,
#  'required': 77713,
#  'claim': 28564,
#  'bonafide': 24470,
#  'beneficiary': 23037,
#  'safety': 80083,
#  'risk': 78497,
#  'involve': 52635,
#  'drug': 36263,
#  'terrorist': 86922,
#  'fund': 43271,
#  'interested': 52352,
#  'carry': 26857,
#  'transaction': 88547,
#  '20': 3486,
#  'assistance': 20504,
#  'expenses': 39908,
#  '75': 11317,
#  'send': 81178,
#  'immediately': 51253,
#  'address': 17095,
#  'use': 91315,
#  'draft': 36117,
#  'agreement': 17878,
#  'guide': 45922,
#  'protect': 73612,
#  'effect': 37696,
#  'change': 27718,
#  'ownership': 68716,
#  'telephone': 86754,
#  'fax': 40806,
#  'numbers': 66252,
#  'notify': 65899,
#  'willingness': 95555,
#  'sending': 81193,
#  'requirement': 77715,
#  'seven': 81425,
#  'working': 96050,
#  'urgent': 91229,
#  'reply': 77619,
#  'reach': 76589,
#  '234': 4261,
#  '80': 12020,
#  '33055024': 5840,
#  'alternative': 18820,
#  'williamsfalana': 95549,
#  'caramail': 26743,
#  'best': 23129,
#  'regards': 77148,
#  '_________________________________________________________': 14706,
#  'envoyez': 38809,
#  'des': 33325,
#  'messages': 61684,
#  'musicaux': 63742,
#  'sur': 85209,
#  'le': 57863,
#  'portable': 72513,
#  'vos': 93244,
#  'amis': 18997,
#  'mobile': 62658,
#  'lycos': 59904,
#  'fr': 42648,
#  'local': 59075,
#  'sms_musicaux': 82853,
#  'request': 77707,
#  'availed': 21048,
#  'chamber': 27698,
#  'commerce': 29497,
#  'given': 44733,
#  'status': 84208,
#  'did': 33957,
#  'disclose': 34255,
#  'actual': 16938,
#  'reasons': 76710,
#  'sought': 83281,
#  'assured': 20537,
#  'reputable': 77699,
#  'trustworthy': 88907,
#  'laurent': 57642,
#  'mpeti': 63207,
#  'kabila': 55472,
#  'jnr': 54573,
#  'son': 83198,
#  'president': 73058,
#  'desire': 33382,
#  'immediate': 51251,
#  'past': 69576,
#  'democratic': 33152,
#  'republic': 77688,
#  'congo': 29990,
#  'africa': 17664,
#  'murdered': 63705,
#  'opposition': 67877,
#  'bodyguards': 24394,
#  'bedroom': 22871,
#  'tuesday': 89061,
#  '16th': 2578,
#  'january': 53844,
#  '2001': 3501,
#  'privilege': 73239,
#  'mandated': 60617,
#  'father': 40762,
#  'colleagues': 29315,
#  'seek': 81052,
#  'operation': 67831,
#  'bank': 22360,
#  'account': 16712,
#  '25m': 4521,
#  'dollars': 34945,
#  'carats': 26744,
#  'diamond': 33915,
#  'treasures': 88683,
#  'vault': 92149,
#  'europe': 39430,
#  'south': 83318,
#  'sources': 83311,
#  'diamonds': 33916,
#  'august': 20858,
#  '2000': 3488,
#  'defence': 32952,
#  'minister': 62207,
#  'meeting': 61462,
#  'cabinet': 26398,
#  'armychief': 20161,
#  'budget': 25347,
#  '700m': 11074,
#  'directed': 34157,
#  'friend': 42927,
#  'frederic': 42767,
#  'kibasa': 56062,
#  'maliba': 60554,
#  'mines': 62181,
#  'party': 69532,
#  'leader': 57873,
#  'known': 56472,
#  'union': 90729,
#  'sacree': 80041,
#  'radicale': 76121,
#  'et': 39292,
#  'ses': 81370,
#  'allies': 18708,
#  'usoral': 91399,
#  'arms': 20158,
#  '200m': 3666,
#  '5th': 9893,
#  'finalized': 41589,
#  'arm': 20145,
#  'deal': 32703,
#  'fkm': 41822,
#  'decided': 32803,
#  'foreigner': 42355,
#  'contest': 30262,
#  'election': 38050,
#  'inspite': 52163,
#  'resolved': 77829,
#  'present': 73040,
#  'pay': 69685,
#  'nominated': 65714,
#  'partnership': 69527,
#  'unanimously': 90408,
#  'agreed': 17875,
#  'entitled': 38738,
#  'successfully': 84916,
#  'nature': 64483,
#  'successful': 84915,
#  'execution': 39762,
#  'require': 77712,
#  'total': 88259,
#  'commitment': 29517,
#  'ensure': 38689,
#  'ends': 38530,
#  'persons': 70626,
#  'involved': 52636,
#  'strict': 84586,
#  'utmost': 91490,
#  'secrecy': 80980,
#  'conclusion': 29819,
#  'proposal': 73556,
#  'acceptable': 16646,
#  'kindly': 56143,
#  'provide': 73660,
#  'box': 24698,
#  'commencement': 29484,
#  'correspondence': 30542,
#  'attention': 20740,
#  'counsel': 30615,
#  'joseph': 54725,
#  'edward': 37606,
#  'count': 30619,
#  'honour': 48102,
#  'secret': 80981,
#  'looking': 59228,
#  'forward': 42510,
#  'thanks': 87167,
#  'irish': 52919,
#  'linux': 58631,
#  'users': 91367,
#  'group': 45712,
#  'ilug': 51126,
#  'mailman': 60393,
#  'listinfo': 58724,
#  'subscription': 84844,
#  'maintainer': 60489,
#  'listmaster': 58729,
#  'substantial': 84864,
#  'monthly': 62910,
#  'income': 51540,
#  'makers': 60528,
#  'voucher': 93258,
#  'systems': 85740,
#  'distribution': 34499,
#  'pending': 70400,
#  '21': 3894,
#  '000': 1,
#  '00': 0,
#  'hotresponders': 48242,
#  'cgi': 27613,
#  'bin': 23627,
#  'varpro': 92122,
#  'vartrack': 92125,
#  'wendy7172': 95164,
#  'good': 45236,
#  'news': 65033,
#  'substancial': 84863,
#  'entire': 38732,
#  'opportunity': 67871,
#  'make': 60515,
#  'month': 62908,
#  'follow': 42229,
#  'ready': 76638,
#  'needed': 64741,
#  'having': 46832,
#  'requested': 77708,
#  'businesses': 25558,
#  'longer': 59210,
#  'aol': 19592,
#  'kone': 56548,
#  'bakar': 22265,
#  'tel': 86719,
#  '225': 4082,
#  '0771': 741,
#  '1719': 2604,
#  'abidjan': 16379,
#  'ivory': 53341,
#  'coast': 29158,
#  'west': 95186,
#  'permit': 70556,
#  'inform': 51860,
#  'going': 45187,
#  'relationship': 77308,
#  'got': 45295,
#  'search': 80915,
#  'esteeming': 39265,
#  'hesitate': 47323,
#  'confide': 29892,
#  'simple': 82172,
#  'child': 27974,
#  'mr': 63280,
#  'mrs': 63319,
#  'coulibaly': 30609,
#  'wealthy': 94952,
#  'cocoa': 29194,
#  'merchant': 61627,
#  'based': 22490,
#  'economic': 37469,
#  'capital': 26696,
#  'poisoned': 72309,
#  'death': 32725,
#  'associates': 20516,
#  'outing': 68458,
#  'meetings': 61463,
#  'mother': 63060,
#  '21st': 3995,
#  'october': 66984,
#  '1994': 2913,
#  'took': 88155,
#  'special': 83501,
#  'dead': 32691,
#  '29th': 4841,
#  'june': 55017,
#  'private': 73228,
#  'hospital': 48198,
#  'secretly': 80988,
#  'called': 26528,
#  'bedside': 22875,
#  'told': 88087,
#  '500': 8927,
#  'sixteen': 82337,
#  'thousand': 87419,
#  'left': 57950,
#  'suspence': 85288,
#  'kin': 56136,
#  'explained': 39940,
#  'wealth': 94947,
#  'foreign': 42352,
#  'partner': 69523,
#  'choice': 28053,
#  'investment': 52605,
#  'purpose': 74147,
#  'sincerely': 82208,
#  'asking': 20411,
#  'following': 42233,
#  'ways': 94341,
#  'transferred': 88561,
#  'serve': 81340,
#  'guardian': 45883,
#  'boy': 24713,
#  '22': 3997,
#  'come': 29436,
#  'willing': 95554,
#  '15': 2339,
#  'compensation': 29622,
#  'effort': 37718,
#  'overseas': 68623,
#  'furthermore': 43313,
#  'indicate': 51683,
#  'opinion': 67847,
#  'assisting': 20508,
#  'believe': 22983,
#  'signify': 82095,
#  'assist': 20503,
#  'appreciate': 19809,
#  'anticaipting': 19459,
#  'hearing': 47080,
#  'soon': 83225,
#  'god': 45156,
#  'bless': 23978,
#  '__________________________________________________________': 14707,
#  'sign': 82070,
#  'personalized': 70616,
#  'sr': 83860,
#  'language': 57500,
#  'en': 38432,
#  'generator': 44258,
#  'microsoft': 62003,
#  'frontpage': 43005,
#  'progid': 73406,
#  'editor': 37557,
#  'windows': 95603,
#  '1252': 2025,
#  'control': 30335,
#  'computer': 29755,
#  '489': 8330,
#  'height': 47157,
#  '54': 9185,
#  '48': 8295,
#  'impact': 51290,
#  'cc0000': 27108,
#  'line': 58568,
#  '990033': 13977,
#  'collapse': 29305,
#  'bordercolordark': 24585,
#  '567': 9317,
#  'bordercolorlight': 24586,
#  'ffff99': 41316,
#  '467': 8224,
#  '555': 9260,
#  '86': 12651,
#  'ff0000': 41235,
#  'tahoma': 86190,
#  'norton': 65833,
#  'systemworks': 85743,
#  'suite': 85010,
#  'roman': 78896,
#  'edition': 37555,
#  '56': 9286,
#  'includes': 51529,
#  'yes': 98554,
#  'feature': 41058,
#  'packed': 69127,
#  'utilities': 91474,
#  'low': 59355,
#  '29': 4793,
#  '99': 13970,
#  '135': 2165,
#  '800000': 12024,
#  '129': 2068,
#  'unwanted': 91011,
#  'hazardous': 46863,
#  'viruses': 92887,
#  'help': 47200,
#  'secure': 81012,
#  'amp': 19047,
#  'valuable': 92057,
#  'files': 41540,
#  'mails': 60404,
#  'safely': 80079,
#  'backup': 22191,
#  'data': 32319,
#  'quick': 75547,
#  'pc': 69756,
#  'performance': 70486,
#  'superior': 85124,
#  'integral': 52274,
#  'diagnostics': 33895,
#  'll': 58888,
#  'repair': 77570,
#  'shop': 81840,
#  '000080': 37,
#  'great': 45565,
#  'combined': 29424,
#  'retail': 77958,
#  'lt': 59561,
#  'shipping': 81777,
#  'gt': 45820,
#  'fall': 40613,
#  'prey': 73130,
#  'destructive': 33432,
#  'hackers': 46445,
#  '44': 8096,
#  '38': 6143,
#  'rgb': 78218,
#  '255': 4477,
#  '14pt': 2333,
#  'weight': 95115,
#  'bold': 24438,
#  '168': 2537,
#  '161': 2471,
#  '77': 11411,
#  'systemworks46': 85745,
#  'htm': 48469,
#  'denotes': 33204,
#  'canadian': 26607,
#  'customers': 31479,
#  'strongly': 84635,
#  'unsolicited': 90939,
#  'mailings': 60385,
#  'sites': 82305,
#  'requesting': 77710,
#  'notified': 65898,
#  'run': 79445,
#  'attained': 20719,
#  'independent': 51631,
#  '3rd': 7683,
#  'overlook': 68593,
#  'management': 60602,
#  '51': 9018,
#  'accept': 16644,
#  'apologies': 19710,
#  'honor': 48096,
#  'requests': 77711,
#  '2102psqq8': 3897,
#  '906dhix6392xdpf7': 13608,
#  '0l26': 1133,
#  'lowest': 59365,
#  'rates': 76350,
#  'available': 21047,
#  'term': 86880,
#  'life': 58442,
#  'insurance': 52249,
#  'moment': 62812,
#  'rate': 76347,
#  'qualify': 75453,
#  'regular': 77202,
#  'smokers': 82829,
#  'accepted': 16648,
#  'newnamedns': 65028,
#  'termlife': 86892,
#  'representing': 77664,
#  'quality': 75457,
#  'nationwide': 64470,
#  'carriers': 26853,
#  'stopthemailplease': 84459,
#  '72': 11179,
#  'hours': 48261,
#  'opportunities': 67870,
#  'seekers': 81057,
#  'thought': 87414,
#  'followings': 42234,
#  'currently': 31433,
#  'hiring': 47630,
#  'home': 48006,
#  'typist': 89387,
#  'clerk': 28698,
#  'secretary': 80983,
#  'supervisor': 85158,
#  'trainer': 88521,
#  'marketer': 60794,
#  'manager': 60604,
#  'weekly': 95092,
#  '1000': 1497,
#  'usd': 91299,
#  'potential': 72648,
#  'experience': 39912,
#  'ok': 67397,
#  'typing': 89386,
#  'sex': 81443,
#  'age': 17749,
#  'apply': 19784,
#  'responsevivek': 77874,
#  'indiatimes': 51680,
#  'subject': 84789,
#  'details': 33442,
#  'spam': 83390,
#  'chance': 27712,
#  'banking': 22366,
#  'interests': 52356,
#  'year': 98499,
#  'settle': 81408,
#  '1993': 2912,
#  'advantage': 17323,
#  'malaysia': 60542,
#  'currencies': 31420,
#  'cellular': 27384,
#  'phones': 71323,
#  'cheap': 27838,
#  'brand': 24872,
#  'motorola': 63090,
#  'siemen': 82037,
#  'models': 62719,
#  'sell': 81130,
#  'hand': 46572,
#  'agent': 17767,
#  'web': 94964,
#  'pages': 69185,
#  'big': 23545,
#  'perfect': 70478,
#  'medicine': 61438,
#  'miracle': 62245,
#  'urine': 91242,
#  'therapy': 87265,
#  'bye': 25863,
#  'surgical': 85234,
#  'knife': 56431,
#  'radiation': 76117,
#  'chemo': 27909,
#  'friends': 42933,
#  'unrine': 90908,
#  'consultation': 30172,
#  'dr': 36107,
#  'lim': 58524,
#  'heng': 47243,
#  'kiap': 56059,
#  'charitable': 27784,
#  'health': 47067,
#  'farm': 40704,
#  'forest': 42370,
#  'reserve': 77779,
#  'area': 20071,
#  'frim': 42953,
#  'kuala': 56820,
#  'lumpur': 59690,
#  'include': 51527,
#  'fasting': 40742,
#  ...}

# %%
# Spliting and Shuffle our Test data

X_train, X_test, y_train, y_test = train_test_split(all_features, # Features
                                                    data.Category, # Labels 
                                                    test_size=0.3, # 30% for testing and 70% for training
                                                    random_state= 88) # Shuffling (everyday i'm shuffling....)

# %%
print('X train shape:', X_train.shape)
print('X test shape:', X_test.shape)
# Out:
# X train shape: (4057, 102694)
# X test shape: (1740, 102694)

# %%
# Creating the classifier and training it!
classifier = MultinomialNB()

classifier.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# Calculating Metrics

nr_correct = (y_test == classifier.predict(X_test)).sum()
nr_incorrect = y_test.size - nr_correct

print(f'{nr_correct} documents classified correctly')
print(f'{nr_incorrect} documents classified incorrectly')
# Out:
# 1650 documents classified correctly
# 90 documents classified incorrectly

# %%
accuracy = nr_correct / (nr_correct + nr_incorrect)
print(f'Model Accuracy is: {accuracy:.2%}')
# Out:
# Model Accuracy is: 94.83%

# %%
# You can also calculate using 'SCORE' Method
classifier.score(X_test, y_test)
# Out:
# 0.9482758620689655

# %%
# Recall
recall = recall_score(y_test, classifier.predict(X_test))
print('Recall Score: {:.2%}'.format(recall))

# Precision
precision = precision_score(y_test, classifier.predict(X_test))
print('Precision Score: {:.2%}'.format(precision))

# F1 Score
f_score = 2 * (precision * recall) / (precision + recall)
print('F1 Score: {:.2%}'.format(f_score))
# Out:
# Recall Score: 85.46%
# Precision Score: 98.14%
# F1 Score: 91.36%

# %%
# Testing with new examples in order to check if our new e-mails are spammy or not

example = ['Get viagra for free now',
           'Need a mortgage?  Reply to arrange a call with a specialist and get a quote',
           'Could you please help me with the project tommorrow?',
           'Hey man, How about a game of golf tomorrow? Please let me know',
           'Ski jumping is a winter sport in which competitors aim to achieve the longest jump after descending from a specially designed ramp on their skis. Along with jump length, competitor\'s style and other factors affect the final score. Ski jumping was first contested in Norway in the late 19th century, and later spread through Europe and North America in the early 20th century. Along with cross-country skiing, it constitutes the traditional group of Nordic skiing disciplines.']

# %%
# 1st let's process our new emails
doc_term_matrix = vectorizer.transform(example)

# %%
# Take the classifier
classifier.predict(doc_term_matrix)
# Out:
# array([1, 1, 0, 0, 0])
